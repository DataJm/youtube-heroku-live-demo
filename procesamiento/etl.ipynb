# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
data = pd.read_csv("../data/MXvideos.csv", encoding="Latin1")

# %%
data.head()
# Out:
#       video_id trending_date  \
# 0  SbOwzAl9ZfQ      17.14.11
# 1  klOV6Xh-DnI      17.14.11
# 2  6L2ZF7Qzsbk      17.14.11
# 3  hcY52MFWMDM      17.14.11
# 4  _OXDcGPVAa4      17.14.11
#
#                                                title  \
# 0                     CapÃ­tulo 12 | MasterChef 2017
# 1  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2           LOUIS CKAGÃ - EL PULSO DE LA REPÃBLICA
# 3   Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4           DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
#
#                channel_title  category_id              publish_time  \
# 0            MasterChef 2017           24  2017-11-13T06:06:22.000Z
# 1   Micky Contreras Martinez           22  2017-11-13T05:11:58.000Z
# 2  El Pulso De La RepÃºblica           25  2017-11-13T17:00:02.000Z
# 3                   Casanare           25  2017-11-13T03:47:10.000Z
# 4                      Musas           26  2017-11-13T19:17:48.000Z
#
# ...

# %%
# !pip install psycopg2
# Out:
# ...
#   Using cached psycopg2-2.9.2-cp38-cp38-win_amd64.whl (1.1 MB)
# ...

# %%
connection_string = "postgresql://vwjpswzrnmptct:f7d3585048d5d8fa64b2bdb0633aa8324f01e3d4ea044a37284ddcc918b9817a@ec2-52-201-195-11.compute-1.amazonaws.com:5432/dd9j1f8aub9l0u"

# %%
engine = create_engine(connection_string)

# %%
data.shape
# Out:
# (40451, 16)

# %%
data.sample(1000).to_sql(name="ratings",con=engine, if_exists="replace")

# %%
pd.read_sql("select count(1) from ratings", engine)
# Out:
#    count
# 0   1000

# %%
data = pd.read_sql("select * from ratings",engine)

# %%
data
# Out:
#      index     video_id trending_date  \
# 0    25105  fkKZH-3DGf8      18.21.03
# 1    15868  LxoGNkLpgZk      18.03.02
# 2    36838  RPMcM_hLgSw      18.26.05
# 3     5408  PKUeabVmcb0      17.11.12
# 4    20347  M_c9dxKS2dQ      18.26.02
# ..     ...          ...           ...
# 995  38561  9pEB3741CxQ      18.04.06
# 996  16585  EW7INZEtIWk      18.07.02
# 997  33930  Kox4CrWLR_8      18.11.05
# 998   5467  GmHrjFIWl6U      17.11.12
# 999  30602  cNws6xmxqM0      18.24.04
#
#                                                  title        channel_title  \
# 0                            EL RASTRO eterna obsesion            EL RASTRO
# 1         Iggy Azalea - Savior (Lyric Video) ft. Quavo  iggyazaleamusicVEVO
# 2    Pugna entre Televisa y Tv Azteca por Serie de ...        Chacaleo. Com
# 3            Audiciones para el Rey LeÃ³n | Pepe & Teo             PepeyTeo
# 4                           6 COSAS QUE NO SABÃAS #24             Tri-line
# ...

# %%
resultado = data.groupby("channel_title")["views","likes"].sum()
# Out:
# C:\Users\manyv\AppData\Local\Temp/ipykernel_9496/2689335484.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   resultado = data.groupby("channel_title")["views","likes"].sum()

# %%
(
        resultado
        .sort_values(by="views", ascending=False)
        .reset_index()
        .loc[:,["channel_title","views"]]
        .head()
#        .to_json(orient="records")
    )
# Out:
#           channel_title     views
# 0  Marvel Entertainment  66637636
# 1            YandelVEVO  33419766
# 2            MalumaVEVO   9863614
# 3         KatyPerryVEVO   8386240
# 4            BeckyGVEVO   6978753
